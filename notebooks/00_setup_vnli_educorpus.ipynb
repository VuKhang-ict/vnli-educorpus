# %% [markdown]
# <a href="https://colab.research.google.com/github/VuKhang-ict/vnli-educorpus/blob/main/notebooks/00_setup_vnli_educorpus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 00_setup_vnli_educorpus
#
# Notebook thiết lập ban đầu cho dự án VNLI-EduCorpus.
#
# ## Mục tiêu
# - Xác nhận notebook đầu tiên đã gắn với repo GitHub
# - Làm điểm bắt đầu cho các notebook xử lý dữ liệu sau này
#
# ## Ghi nhớ
# - GitHub là nguồn chuẩn của cấu trúc dự án
# - Các file CSV nền đang nằm trong `data/metadata/` và `data/samples/`
# - Chưa dùng notebook này để xử lý dữ liệu lớn

# %%
print("VNLI-EduCorpus: Colab notebook đầu tiên đã được tạo.")
print("Mục tiêu hiện tại: xác nhận notebook đã lưu vào đúng GitHub repo.")
# Out:
# VNLI-EduCorpus: Colab notebook đầu tiên đã được tạo.
# Mục tiêu hiện tại: xác nhận notebook đã lưu vào đúng GitHub repo.
